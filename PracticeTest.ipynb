# %%
# Here is something

# %%
import pandas as pd
data = {"a":23, "b": 30, "c": 40}
series_data = pd.Series(data)
print(series_data)
print(series_data.head())
# Out:
# a    23
# b    30
# c    40
# dtype: int64
# a    23
# b    30
# c    40
# dtype: int64
